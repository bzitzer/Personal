# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import math
x = [1,2,3,4]
y = math.ceil(math.sqrt(x[1])+1)
b = 4
while b < 100:
    b = b*b
    print(b,end=',')
print(y)
# Out:
# 16,256,3

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10,10)
plt.plot(x, x**3+1)
#plt.title('A simple chirp')
plt.show()
print(x)
# Out:
# [-10.          -9.59183673  -9.18367347  -8.7755102   -8.36734694
#   -7.95918367  -7.55102041  -7.14285714  -6.73469388  -6.32653061
#   -5.91836735  -5.51020408  -5.10204082  -4.69387755  -4.28571429
#   -3.87755102  -3.46938776  -3.06122449  -2.65306122  -2.24489796
#   -1.83673469  -1.42857143  -1.02040816  -0.6122449   -0.20408163
#    0.20408163   0.6122449    1.02040816   1.42857143   1.83673469
#    2.24489796   2.65306122   3.06122449   3.46938776   3.87755102
#    4.28571429   4.69387755   5.10204082   5.51020408   5.91836735
#    6.32653061   6.73469388   7.14285714   7.55102041   7.95918367
#    8.36734694   8.7755102    9.18367347   9.59183673  10.        ]

# %%
y = np.exp(-x)
plt.plot(x,y)
print(y)
plt.show()
# Out:
# [2.20264658e+04 1.46447434e+04 9.73685520e+03 6.47374603e+03
#  4.30420159e+03 2.86173589e+03 1.90268325e+03 1.26503762e+03
#  8.41085969e+02 5.59213097e+02 3.71804191e+02 2.47201571e+02
#  1.64356988e+02 1.09276083e+02 7.26544242e+01 4.83057703e+01
#  3.21170729e+01 2.13536885e+01 1.41974337e+01 9.43945230e+00
#  6.27601167e+00 4.17273388e+00 2.77432691e+00 1.84456762e+00
#  1.22639826e+00 8.15395806e-01 5.42132470e-01 3.60447789e-01
#  2.39651036e-01 1.59336861e-01 1.05938350e-01 7.04352645e-02
#  4.68303169e-02 3.11360877e-02 2.07014606e-02 1.37637867e-02
#  9.15113329e-03 6.08431691e-03 4.04528173e-03 2.68958776e-03
#  1.78822707e-03 1.18893911e-03 7.90490323e-04 5.25573554e-04
#  3.49438257e-04 2.32331126e-04 1.54470070e-04 1.02702565e-04
#  6.82838870e-05 4.53999298e-05]

# %%
z = np.linspace(0,10)

plt.imshow(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1a7d84f54256> in <module>()
#       1 z = np.linspace(0,10)
# ----> 2 plt.colormap(x,y,x+y)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'colormap'
